# %%
import nltk
nltk.download('punkt') 
import string
import tweepy
import json

from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from tweepy import OAuthHandler

# Seteamos las credenciales
consumer_key = 'X5EqKwcj2QSpcSlsqoBi29eCb'
consumer_secret = '6i9NqIFCGOrhZzUTlRe8lPTzevyEj8eA8lm8eWwF9MMrabHanq'
access_token = '982692299648925696-MlIqFRw5K8vNOmoGWD4bMoX0dpGo98n'
access_secret = 'at2hhW8W6wGz3mmgxJPCJSnu0UC6wku4l9iJ4U5CzxTdI'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

# Nos autenticamos en la API de tweepi
api = tweepy.API(auth)

# Obtenemos la información de nosotros mismos y la mostramos
user = api.me()
 
print('Name: ' + user.name)
print('Location: ' + user.location)
print('Friends: ' + str(user.followers_count))
print('Created: ' + str(user.created_at))
print('Description: ' + str(user.description))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Name: Jonathan Zarama
# Location:
# Friends: 4
# Created: 2018-04-07 18:51:16
# Description:

# %%
# Mostramos un tweet
for status in tweepy.Cursor(api.home_timeline).items(1):
    print(word_tokenize(status.text))
# Out:
# ['#', 'Chichichilele', '#', 'munmunmundial', '#', 'chile', 'https', ':', '//t.co/RmBDhRFbyW']

# %%
# Mostramos un JSON con la información del tweet anterior
for status in tweepy.Cursor(api.home_timeline).items(1):
    print(json.dumps(status._json, indent=2))
# Out:
# {
#   "in_reply_to_screen_name": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_status_id": null,
#   "entities": {
#     "user_mentions": [],
#     "urls": [
#       {
#         "indices": [
#           37,
#           60
#         ],
#         "display_url": "twitter.com/Tito_Leiva/sta\u2026",
#         "expanded_url": "https://twitter.com/Tito_Leiva/status/996453942296039425",
#         "url": "https://t.co/RmBDhRFbyW"
#       }
#     ],
#     "symbols": [],
#     "hashtags": [
#       {
#         "indices": [
#           0,
#           14
#         ],
#         "text": "Chichichilele"
#       },
#       {
#         "indices": [
#           15,
#           29
#         ],
#         "text": "munmunmundial"
#       },
#       {
#         "indices": [
#           30,
#           36
#         ],
#         "text": "chile"
#       }
#     ]
#   },
#   "retweeted": false,
#   "quoted_status_id": 996453942296039425,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "id_str": "996455235269943296",
#   "truncated": false,
#   "place": null,
#   "possibly_sensitive": false,
#   "coordinates": null,
#   "text": "#Chichichilele #munmunmundial #chile https://t.co/RmBDhRFbyW",
#   "id": 996455235269943296,
#   "user": {
#     "translator_type": "none",
#     "following": false,
#     "description": "",
#     "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#     "has_extended_profile": false,
#     "profile_link_color": "1DA1F2",
#     "entities": {
#       "description": {
#         "urls": []
#       }
#     },
#     "protected": false,
#     "notifications": false,
#     "verified": false,
#     "default_profile_image": true,
#     "profile_background_color": "F5F8FA",
#     "listed_count": 0,
#     "utc_offset": null,
#     "profile_background_tile": false,
#     "geo_enabled": false,
#     "profile_sidebar_fill_color": "DDEEF6",
#     "id_str": "982692299648925696",
#     "is_translator": false,
#     "profile_text_color": "333333",
#     "statuses_count": 7,
#     "profile_use_background_image": true,
#     "contributors_enabled": false,
#     "follow_request_sent": false,
#     "profile_background_image_url_https": null,
#     "favourites_count": 1,
#     "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#     "id": 982692299648925696,
#     "profile_background_image_url": null,
#     "lang": "es",
#     "time_zone": null,
#     "friends_count": 8,
#     "is_translation_enabled": false,
#     "screen_name": "JonathanzPri",
#     "url": null,
#     "followers_count": 4,
#     "profile_sidebar_border_color": "C0DEED",
#     "location": "",
#     "default_profile": true,
#     "created_at": "Sat Apr 07 18:51:16 +0000 2018",
#     "name": "Jonathan Zarama"
#   },
#   "lang": "und",
#   "quoted_status_id_str": "996453942296039425",
#   "possibly_sensitive_appealable": false,
#   "favorited": false,
#   "quoted_status": {
#     "in_reply_to_screen_name": "JonathanzPri",
#     "in_reply_to_status_id_str": "996453760200265730",
#     "in_reply_to_status_id": 996453760200265730,
#     "entities": {
#       "user_mentions": [
#         {
#           "indices": [
#             0,
#             13
#           ],
#           "id_str": "982692299648925696",
#           "id": 982692299648925696,
#           "screen_name": "JonathanzPri",
#           "name": "Jonathan Zarama"
#         }
#       ],
#       "urls": [],
#       "symbols": [],
#       "hashtags": []
#     },
#     "retweeted": false,
#     "in_reply_to_user_id": 982692299648925696,
#     "in_reply_to_user_id_str": "982692299648925696",
#     "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "id_str": "996453942296039425",
#     "truncated": false,
#     "place": null,
#     "coordinates": null,
#     "text": "@JonathanzPri Mk te recuerdo el 4-2 de Chile a Colombia",
#     "id": 996453942296039425,
#     "favorited": false,
#     "lang": "es",
#     "user": {
#       "translator_type": "none",
#       "following": true,
#       "description": "Ingeniero Civil Industrial y Comput\u00edn. Futbolero, Judoka, Ciclista, Guitarrero.",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/847827480958390274/bBWysE7r_normal.jpg",
#       "has_extended_profile": true,
#       "profile_link_color": "0084B4",
#       "entities": {
#         "description": {
#           "urls": []
#         },
#         "url": {
#           "urls": [
#             {
#               "indices": [
#                 0,
#                 22
#               ],
#               "display_url": "facebook.com/celeiva815",
#               "expanded_url": "http://www.facebook.com/celeiva815",
#               "url": "http://t.co/xZVVVjjYeV"
#             }
#           ]
#         }
#       },
#       "protected": false,
#       "notifications": false,
#       "verified": false,
#       "default_profile_image": false,
#       "profile_background_color": "C0DEED",
#       "listed_count": 5,
#       "utc_offset": -14400,
#       "profile_background_tile": true,
#       "geo_enabled": true,
#       "profile_sidebar_fill_color": "DDEEF6",
#       "id_str": "154641255",
#       "is_translator": false,
#       "profile_text_color": "333333",
#       "statuses_count": 671,
#       "profile_use_background_image": true,
#       "contributors_enabled": false,
#       "follow_request_sent": false,
#       "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/338612746/colocolo.jpg",
#       "favourites_count": 68,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/847827480958390274/bBWysE7r_normal.jpg",
#       "id": 154641255,
#       "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/338612746/colocolo.jpg",
#       "lang": "es",
#       "time_zone": "Santiago",
#       "friends_count": 140,
#       "is_translation_enabled": false,
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/154641255/1490972873",
#       "screen_name": "Tito_Leiva",
#       "url": "http://t.co/xZVVVjjYeV",
#       "followers_count": 170,
#       "profile_sidebar_border_color": "C0DEED",
#       "location": "\u00d1u\u00f1oa, Chile",
#       "default_profile": false,
#       "created_at": "Fri Jun 11 20:23:13 +0000 2010",
#       "name": "Tito Leiva"
#     },
#     "retweet_count": 0,
#     "is_quote_status": false,
#     "geo": null,
#     "created_at": "Tue May 15 18:15:07 +0000 2018",
#     "favorite_count": 0,
#     "contributors": null
#   },
#   "retweet_count": 0,
#   "is_quote_status": true,
#   "geo": null,
#   "created_at": "Tue May 15 18:20:15 +0000 2018",
#   "favorite_count": 0,
#   "contributors": null
# }

# %%
#Mostramos una lista con 10 de nuestros amigos 
for friend in tweepy.Cursor(api.friends).items(10):
    print(json.dumps(friend._json, indent=2))
# Out:
# {
#   "blocked_by": false,
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#     "description": {
#       "urls": []
#     },
#     "url": {
#       "urls": [
#         {
#           "indices": [
#             0,
#             22
#           ],
#           "display_url": "facebook.com/celeiva815",
#           "expanded_url": "http://www.facebook.com/celeiva815",
#           "url": "http://t.co/xZVVVjjYeV"
#         }
#       ]
#     }
#   },
#   "notifications": false,
#   "listed_count": 5,
#   "geo_enabled": true,
#   "default_profile": false,
#   "id_str": "154641255",
#   "status": {
#     "in_reply_to_screen_name": "JonathanzPri",
#     "in_reply_to_status_id_str": "996453760200265730",
#     "in_reply_to_status_id": 996453760200265730,
#     "entities": {
#       "user_mentions": [
#         {
#           "indices": [
#             0,
#             13
#           ],
#           "id_str": "982692299648925696",
#           "id": 982692299648925696,
#           "screen_name": "JonathanzPri",
#           "name": "Jonathan Zarama"
#         }
#       ],
#       "urls": [],
#       "symbols": [],
#       "hashtags": []
#     },
#     "in_reply_to_user_id": 982692299648925696,
#     "in_reply_to_user_id_str": "982692299648925696",
#     "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "id_str": "996453942296039425",
#     "contributors": null,
#     "truncated": false,
#     "place": null,
#     "coordinates": null,
#     "text": "@JonathanzPri Mk te recuerdo el 4-2 de Chile a Colombia",
#     "id": 996453942296039425,
#     "favorited": false,
#     "lang": "es",
#     "retweet_count": 0,
#     "is_quote_status": false,
#     "geo": null,
#     "created_at": "Tue May 15 18:15:07 +0000 2018",
#     "favorite_count": 0,
#     "retweeted": false
#   },
#   "favourites_count": 68,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/847827480958390274/bBWysE7r_normal.jpg",
#   "profile_background_tile": true,
#   "profile_link_color": "0084B4",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/338612746/colocolo.jpg",
#   "statuses_count": 671,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/154641255/1490972873",
#   "screen_name": "Tito_Leiva",
#   "muting": false,
#   "profile_sidebar_border_color": "C0DEED",
#   "contributors_enabled": false,
#   "friends_count": 140,
#   "is_translation_enabled": false,
#   "translator_type": "none",
#   "following": true,
#   "description": "Ingeniero Civil Industrial y Comput\u00edn. Futbolero, Judoka, Ciclista, Guitarrero.",
#   "has_extended_profile": true,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/847827480958390274/bBWysE7r_normal.jpg",
#   "protected": false,
#   "live_following": false,
#   "is_translator": false,
#   "profile_background_color": "C0DEED",
#   "utc_offset": -14400,
#   "created_at": "Fri Jun 11 20:23:13 +0000 2010",
#   "verified": false,
#   "profile_text_color": "333333",
#   "default_profile_image": false,
#   "profile_use_background_image": true,
#   "location": "\u00d1u\u00f1oa, Chile",
#   "follow_request_sent": false,
#   "time_zone": "Santiago",
#   "id": 154641255,
#   "lang": "es",
#   "blocking": false,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/338612746/colocolo.jpg",
#   "url": "http://t.co/xZVVVjjYeV",
#   "followers_count": 170,
#   "name": "Tito Leiva"
# }
# {
#   "blocked_by": false,
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#     "description": {
#       "urls": []
#     }
#   },
#   "notifications": false,
#   "listed_count": 0,
#   "geo_enabled": false,
#   "default_profile": true,
#   "id_str": "2379338676",
#   "status": {
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_status_id": null,
#     "entities": {
#       "user_mentions": [],
#       "urls": [],
#       "symbols": [],
#       "media": [
#         {
#           "media_url": "http://pbs.twimg.com/media/DamgEGGX0AE8tvQ.jpg",
#           "display_url": "pic.twitter.com/u7n7ZJFvee",
#           "media_url_https": "https://pbs.twimg.com/media/DamgEGGX0AE8tvQ.jpg",
#           "type": "photo",
#           "url": "https://t.co/u7n7ZJFvee",
#           "id": 984493985774424065,
#           "indices": [
#             0,
#             23
#           ],
#           "id_str": "984493985774424065",
#           "expanded_url": "https://twitter.com/adeochobe/status/984494009056972800/photo/1",
#           "sizes": {
#             "small": {
#               "resize": "fit",
#               "h": 443,
#               "w": 680
#             },
#             "thumb": {
#               "resize": "crop",
#               "h": 150,
#               "w": 150
#             },
#             "large": {
#               "resize": "fit",
#               "h": 833,
#               "w": 1280
#             },
#             "medium": {
#               "resize": "fit",
#               "h": 781,
#               "w": 1200
#             }
#           }
#         }
#       ],
#       "hashtags": []
#     },
#     "retweeted": false,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "extended_entities": {
#       "media": [
#         {
#           "media_url": "http://pbs.twimg.com/media/DamgEGGX0AE8tvQ.jpg",
#           "display_url": "pic.twitter.com/u7n7ZJFvee",
#           "media_url_https": "https://pbs.twimg.com/media/DamgEGGX0AE8tvQ.jpg",
#           "type": "photo",
#           "url": "https://t.co/u7n7ZJFvee",
#           "id": 984493985774424065,
#           "indices": [
#             0,
#             23
#           ],
#           "id_str": "984493985774424065",
#           "expanded_url": "https://twitter.com/adeochobe/status/984494009056972800/photo/1",
#           "sizes": {
#             "small": {
#               "resize": "fit",
#               "h": 443,
#               "w": 680
#             },
#             "thumb": {
#               "resize": "crop",
#               "h": 150,
#               "w": 150
#             },
#             "large": {
#               "resize": "fit",
#               "h": 833,
#               "w": 1280
#             },
#             "medium": {
#               "resize": "fit",
#               "h": 781,
#               "w": 1200
#             }
#           }
#         }
#       ]
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "id_str": "984494009056972800",
#     "truncated": false,
#     "place": null,
#     "possibly_sensitive": false,
#     "coordinates": null,
#     "text": "https://t.co/u7n7ZJFvee",
#     "id": 984494009056972800,
#     "favorited": false,
#     "lang": "und",
#     "retweet_count": 0,
#     "is_quote_status": false,
#     "geo": null,
#     "created_at": "Thu Apr 12 18:10:37 +0000 2018",
#     "favorite_count": 0,
#     "contributors": null
#   },
#   "favourites_count": 54,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/599679818289029120/GadUkrdp_normal.jpg",
#   "profile_background_tile": false,
#   "profile_link_color": "1DA1F2",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "statuses_count": 70,
#   "screen_name": "adeochobe",
#   "muting": false,
#   "profile_sidebar_border_color": "C0DEED",
#   "contributors_enabled": false,
#   "friends_count": 49,
#   "is_translation_enabled": false,
#   "translator_type": "none",
#   "following": true,
#   "description": "",
#   "has_extended_profile": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/599679818289029120/GadUkrdp_normal.jpg",
#   "protected": false,
#   "live_following": false,
#   "is_translator": false,
#   "profile_background_color": "C0DEED",
#   "utc_offset": null,
#   "created_at": "Sat Mar 08 21:37:21 +0000 2014",
#   "verified": false,
#   "profile_text_color": "333333",
#   "default_profile_image": false,
#   "profile_use_background_image": true,
#   "location": "",
#   "follow_request_sent": false,
#   "time_zone": null,
#   "id": 2379338676,
#   "lang": "es",
#   "blocking": false,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "url": null,
#   "followers_count": 23,
#   "name": "Adela Ochoa Betancou"
# }
# {
#   "blocked_by": false,
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#     "description": {
#       "urls": []
#     }
#   },
#   "notifications": false,
#   "listed_count": 0,
#   "geo_enabled": true,
#   "default_profile": true,
#   "id_str": "382437138",
#   "status": {
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_status_id": null,
#     "entities": {
#       "user_mentions": [
#         {
#           "indices": [
#             3,
#             14
#           ],
#           "id_str": "32211946",
#           "id": 32211946,
#           "screen_name": "HassNassar",
#           "name": "Hassan Nassar"
#         }
#       ],
#       "urls": [],
#       "symbols": [],
#       "hashtags": []
#     },
#     "retweeted": false,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "id_str": "995997285703213056",
#     "truncated": false,
#     "place": null,
#     "coordinates": null,
#     "text": "RT @HassNassar: Esta campa\u00f1a presidencial ya nos dej\u00f3 claro que todos los candidatos son muy capaces de llenar plazas con much\u00edsima gente.\u2026",
#     "id": 995997285703213056,
#     "favorited": false,
#     "lang": "es",
#     "retweeted_status": {
#       "in_reply_to_screen_name": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_status_id": null,
#       "entities": {
#         "user_mentions": [],
#         "urls": [
#           {
#             "indices": [
#               117,
#               140
#             ],
#             "display_url": "twitter.com/i/web/status/9\u2026",
#             "expanded_url": "https://twitter.com/i/web/status/995773882912174083",
#             "url": "https://t.co/hs01KhJibG"
#           }
#         ],
#         "symbols": [],
#         "hashtags": []
#       },
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "id_str": "995773882912174083",
#       "contributors": null,
#       "truncated": true,
#       "place": null,
#       "coordinates": null,
#       "text": "Esta campa\u00f1a presidencial ya nos dej\u00f3 claro que todos los candidatos son muy capaces de llenar plazas con much\u00edsima\u2026 https://t.co/hs01KhJibG",
#       "id": 995773882912174083,
#       "favorited": false,
#       "lang": "es",
#       "retweet_count": 2581,
#       "is_quote_status": false,
#       "geo": null,
#       "created_at": "Sun May 13 21:12:48 +0000 2018",
#       "favorite_count": 4653,
#       "retweeted": false
#     },
#     "retweet_count": 2581,
#     "is_quote_status": false,
#     "geo": null,
#     "created_at": "Mon May 14 12:00:32 +0000 2018",
#     "favorite_count": 0,
#     "contributors": null
#   },
#   "favourites_count": 465,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/989818836579966976/kvFkvkTO_normal.jpg",
#   "profile_background_tile": false,
#   "profile_link_color": "1DA1F2",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "statuses_count": 184,
#   "screen_name": "laverdef72",
#   "muting": false,
#   "profile_sidebar_border_color": "C0DEED",
#   "contributors_enabled": false,
#   "friends_count": 138,
#   "is_translation_enabled": false,
#   "translator_type": "none",
#   "following": true,
#   "description": "",
#   "has_extended_profile": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/989818836579966976/kvFkvkTO_normal.jpg",
#   "protected": false,
#   "live_following": false,
#   "is_translator": false,
#   "profile_background_color": "C0DEED",
#   "utc_offset": null,
#   "created_at": "Fri Sep 30 02:17:09 +0000 2011",
#   "verified": false,
#   "profile_text_color": "333333",
#   "default_profile_image": false,
#   "profile_use_background_image": true,
#   "location": "Palmira - Valle - Colombia",
#   "follow_request_sent": false,
#   "time_zone": null,
#   "id": 382437138,
#   "lang": "es",
#   "blocking": false,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "url": null,
#   "followers_count": 41,
#   "name": "Carlos Laverde"
# }
# {
#   "blocked_by": false,
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#     "description": {
#       "urls": []
#     }
#   },
#   "notifications": false,
#   "listed_count": 0,
#   "geo_enabled": true,
#   "default_profile": true,
#   "id_str": "532406192",
#   "status": {
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_status_id": null,
#     "entities": {
#       "user_mentions": [
#         {
#           "indices": [
#             41,
#             53
#           ],
#           "id_str": "328515890",
#           "id": 328515890,
#           "screen_name": "FndoGaviria",
#           "name": "Fernando Gaviria"
#         }
#       ],
#       "urls": [
#         {
#           "indices": [
#             83,
#             106
#           ],
#           "display_url": "twitter.com/ColCiclismo/st\u2026",
#           "expanded_url": "https://twitter.com/ColCiclismo/status/995806258107166720",
#           "url": "https://t.co/40S8YBKRB1"
#         }
#       ],
#       "symbols": [],
#       "hashtags": []
#     },
#     "retweeted": false,
#     "quoted_status_id": 995806258107166720,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "id_str": "996274284074012672",
#     "truncated": false,
#     "place": {
#       "bounding_box": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -76.6073349978781,
#               3.43958600373312
#             ],
#             [
#               -76.0899099989576,
#               3.43958600373312
#             ],
#             [
#               -76.0899099989576,
#               3.7012710035175
#             ],
#             [
#               -76.6073349978781,
#               3.7012710035175
#             ]
#           ]
#         ]
#       },
#       "place_type": "city",
#       "url": "https://api.twitter.com/1.1/geo/id/0083e91b64f919f4.json",
#       "id": "0083e91b64f919f4",
#       "full_name": "Palmira, Colombia",
#       "country": "Colombia",
#       "contained_within": [],
#       "attributes": {},
#       "country_code": "CO",
#       "name": "Palmira"
#     },
#     "possibly_sensitive": false,
#     "coordinates": null,
#     "text": "\u00a1Impresionante! Que bien nos representas @FndoGaviria ... Eres Orgullo Colombiano. https://t.co/40S8YBKRB1",
#     "id": 996274284074012672,
#     "favorited": false,
#     "lang": "es",
#     "quoted_status_id_str": "995806258107166720",
#     "retweet_count": 0,
#     "is_quote_status": true,
#     "geo": null,
#     "created_at": "Tue May 15 06:21:13 +0000 2018",
#     "favorite_count": 0,
#     "contributors": null
#   },
#   "favourites_count": 1298,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/932607636662611968/rBxT4c-2_normal.jpg",
#   "profile_background_tile": false,
#   "profile_link_color": "1DA1F2",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "statuses_count": 552,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/532406192/1511186013",
#   "screen_name": "vomp0896",
#   "muting": false,
#   "profile_sidebar_border_color": "C0DEED",
#   "contributors_enabled": false,
#   "friends_count": 495,
#   "is_translation_enabled": false,
#   "translator_type": "none",
#   "following": true,
#   "description": "Amante al F\u00fatbol y la Pol\u00edtica",
#   "has_extended_profile": true,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/932607636662611968/rBxT4c-2_normal.jpg",
#   "protected": false,
#   "live_following": false,
#   "is_translator": false,
#   "profile_background_color": "C0DEED",
#   "utc_offset": -18000,
#   "created_at": "Wed Mar 21 17:35:28 +0000 2012",
#   "verified": false,
#   "profile_text_color": "333333",
#   "default_profile_image": false,
#   "profile_use_background_image": true,
#   "location": "Palmira",
#   "follow_request_sent": false,
#   "time_zone": "America/Bogota",
#   "id": 532406192,
#   "lang": "es",
#   "blocking": false,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "url": null,
#   "followers_count": 136,
#   "name": "Victor Manuel Ochoa"
# }
# {
#   "blocked_by": false,
#   "profile_sidebar_fill_color": "A0C5C7",
#   "entities": {
#     "description": {
#       "urls": []
#     },
#     "url": {
#       "urls": [
#         {
#           "indices": [
#             0,
#             23
#           ],
#           "display_url": "leslylaverde.tumblr.com",
#           "expanded_url": "http://leslylaverde.tumblr.com/",
#           "url": "https://t.co/VEM0EXi1Th"
#         }
#       ]
#     }
#   },
#   "notifications": false,
#   "listed_count": 1,
#   "geo_enabled": true,
#   "default_profile": false,
#   "id_str": "86435080",
#   "status": {
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_status_id": null,
#     "entities": {
#       "user_mentions": [
#         {
#           "indices": [
#             3,
#             17
#           ],
#           "id_str": "52192814",
#           "id": 52192814,
#           "screen_name": "Hematocritica",
#           "name": "Virginia"
#         }
#       ],
#       "urls": [],
#       "symbols": [],
#       "hashtags": []
#     },
#     "retweeted": false,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "id_str": "996391535661998080",
#     "truncated": false,
#     "place": null,
#     "coordinates": null,
#     "text": "RT @Hematocritica: \u00daltimamente veo a mis ex todos felices involucrados en relaciones sanas y fruct\u00edferas y pienso que tal vez la piroba era\u2026",
#     "id": 996391535661998080,
#     "favorited": false,
#     "lang": "es",
#     "retweeted_status": {
#       "in_reply_to_screen_name": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_status_id": null,
#       "entities": {
#         "user_mentions": [],
#         "urls": [],
#         "symbols": [],
#         "hashtags": []
#       },
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "id_str": "996168968355409920",
#       "contributors": null,
#       "truncated": false,
#       "place": null,
#       "coordinates": null,
#       "text": "\u00daltimamente veo a mis ex todos felices involucrados en relaciones sanas y fruct\u00edferas y pienso que tal vez la piroba era yop",
#       "id": 996168968355409920,
#       "favorited": false,
#       "lang": "es",
#       "retweet_count": 101,
#       "is_quote_status": false,
#       "geo": null,
#       "created_at": "Mon May 14 23:22:44 +0000 2018",
#       "favorite_count": 666,
#       "retweeted": false
#     },
#     "retweet_count": 101,
#     "is_quote_status": false,
#     "geo": null,
#     "created_at": "Tue May 15 14:07:08 +0000 2018",
#     "favorite_count": 0,
#     "contributors": null
#   },
#   "favourites_count": 3950,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/994589645152423936/E_UF-2xh_normal.jpg",
#   "profile_background_tile": false,
#   "profile_link_color": "009999",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/729355106/024d74bf7c4a99f499665d69c4fbadff.jpeg",
#   "statuses_count": 3075,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/86435080/1520027301",
#   "screen_name": "Lesly_Laverde",
#   "muting": false,
#   "profile_sidebar_border_color": "FFFFFF",
#   "contributors_enabled": false,
#   "friends_count": 171,
#   "is_translation_enabled": false,
#   "translator_type": "none",
#   "following": true,
#   "description": "\ud83d\udccd\ud83c\udde8\ud83c\uddf4\ud83d\udccd\ud83c\uddea\ud83c\uddf8\u26bd\ufe0f\ud83c\udfc0\ud83c\udfc8\u26be\ufe0f\ud83c\udfc9\ud83c\udfbe",
#   "has_extended_profile": true,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/994589645152423936/E_UF-2xh_normal.jpg",
#   "protected": false,
#   "live_following": false,
#   "is_translator": false,
#   "profile_background_color": "131516",
#   "utc_offset": 7200,
#   "created_at": "Sat Oct 31 01:09:26 +0000 2009",
#   "verified": false,
#   "profile_text_color": "333333",
#   "default_profile_image": false,
#   "profile_use_background_image": false,
#   "location": "",
#   "follow_request_sent": false,
#   "time_zone": "Madrid",
#   "id": 86435080,
#   "lang": "es",
#   "blocking": false,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/729355106/024d74bf7c4a99f499665d69c4fbadff.jpeg",
#   "url": "https://t.co/VEM0EXi1Th",
#   "followers_count": 336,
#   "name": "Lesly Laverde O."
# }
# {
#   "blocked_by": false,
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#     "description": {
#       "urls": []
#     }
#   },
#   "notifications": false,
#   "listed_count": 0,
#   "geo_enabled": false,
#   "default_profile": true,
#   "id_str": "462943965",
#   "status": {
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_status_id": null,
#     "entities": {
#       "user_mentions": [
#         {
#           "indices": [
#             3,
#             12
#           ],
#           "id_str": "214489279",
#           "id": 214489279,
#           "screen_name": "GW2Spain",
#           "name": "Guild Wars 2 Spain"
#         }
#       ],
#       "urls": [
#         {
#           "indices": [
#             99,
#             122
#           ],
#           "display_url": "guildwars2-spain.com/gw2spain/sorte\u2026",
#           "expanded_url": "http://www.guildwars2-spain.com/gw2spain/sorteos/1329-celebramos-el-lanzamiento-de-guild-wars-2-heart-of-thorns-con-un-sorteo-a-lo-grande",
#           "url": "https://t.co/POrIfh6kEQ"
#         }
#       ],
#       "symbols": [],
#       "hashtags": []
#     },
#     "retweeted": false,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "id_str": "660141392119861248",
#     "truncated": false,
#     "place": null,
#     "possibly_sensitive": false,
#     "coordinates": null,
#     "text": "RT @GW2Spain: Celebramos el lanzamiento de Guild Wars 2 Heart of Thorns con un sorteo a lo grande: https://t.co/POrIfh6kEQ https://t.co/VnC\u2026",
#     "id": 660141392119861248,
#     "favorited": false,
#     "lang": "es",
#     "retweeted_status": {
#       "in_reply_to_screen_name": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_status_id": null,
#       "entities": {
#         "user_mentions": [],
#         "urls": [
#           {
#             "indices": [
#               85,
#               108
#             ],
#             "display_url": "guildwars2-spain.com/gw2spain/sorte\u2026",
#             "expanded_url": "http://www.guildwars2-spain.com/gw2spain/sorteos/1329-celebramos-el-lanzamiento-de-guild-wars-2-heart-of-thorns-con-un-sorteo-a-lo-grande",
#             "url": "https://t.co/POrIfh6kEQ"
#           }
#         ],
#         "symbols": [],
#         "media": [
#           {
#             "media_url": "http://pbs.twimg.com/media/CRxzottWEAA8XHe.jpg",
#             "display_url": "pic.twitter.com/VnCaUkfQYA",
#             "media_url_https": "https://pbs.twimg.com/media/CRxzottWEAA8XHe.jpg",
#             "type": "photo",
#             "url": "https://t.co/VnCaUkfQYA",
#             "id": 656526788990996480,
#             "indices": [
#               109,
#               132
#             ],
#             "id_str": "656526788990996480",
#             "expanded_url": "https://twitter.com/GW2Spain/status/656526789494349824/photo/1",
#             "sizes": {
#               "small": {
#                 "resize": "fit",
#                 "h": 403,
#                 "w": 680
#               },
#               "thumb": {
#                 "resize": "crop",
#                 "h": 150,
#                 "w": 150
#               },
#               "large": {
#                 "resize": "fit",
#                 "h": 829,
#                 "w": 1400
#               },
#               "medium": {
#                 "resize": "fit",
#                 "h": 711,
#                 "w": 1200
#               }
#             }
#           }
#         ],
#         "hashtags": []
#       },
#       "retweeted": false,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "extended_entities": {
#         "media": [
#           {
#             "media_url": "http://pbs.twimg.com/media/CRxzottWEAA8XHe.jpg",
#             "display_url": "pic.twitter.com/VnCaUkfQYA",
#             "media_url_https": "https://pbs.twimg.com/media/CRxzottWEAA8XHe.jpg",
#             "type": "photo",
#             "url": "https://t.co/VnCaUkfQYA",
#             "id": 656526788990996480,
#             "indices": [
#               109,
#               132
#             ],
#             "id_str": "656526788990996480",
#             "expanded_url": "https://twitter.com/GW2Spain/status/656526789494349824/photo/1",
#             "sizes": {
#               "small": {
#                 "resize": "fit",
#                 "h": 403,
#                 "w": 680
#               },
#               "thumb": {
#                 "resize": "crop",
#                 "h": 150,
#                 "w": 150
#               },
#               "large": {
#                 "resize": "fit",
#                 "h": 829,
#                 "w": 1400
#               },
#               "medium": {
#                 "resize": "fit",
#                 "h": 711,
#                 "w": 1200
#               }
#             }
#           }
#         ]
#       },
#       "source": "<a href=\"https://postcron.com\" rel=\"nofollow\">Postcron App</a>",
#       "id_str": "656526789494349824",
#       "truncated": false,
#       "place": null,
#       "possibly_sensitive": false,
#       "coordinates": null,
#       "text": "Celebramos el lanzamiento de Guild Wars 2 Heart of Thorns con un sorteo a lo grande: https://t.co/POrIfh6kEQ https://t.co/VnCaUkfQYA",
#       "id": 656526789494349824,
#       "favorited": false,
#       "lang": "es",
#       "retweet_count": 440,
#       "is_quote_status": false,
#       "geo": null,
#       "created_at": "Tue Oct 20 17:45:58 +0000 2015",
#       "favorite_count": 253,
#       "contributors": null
#     },
#     "retweet_count": 440,
#     "is_quote_status": false,
#     "geo": null,
#     "created_at": "Fri Oct 30 17:09:07 +0000 2015",
#     "favorite_count": 0,
#     "contributors": null
#   },
#   "favourites_count": 0,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/996035870829547522/U7gj4B38_normal.jpg",
#   "profile_background_tile": false,
#   "profile_link_color": "1DA1F2",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "statuses_count": 8,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/462943965/1526308471",
#   "screen_name": "rgenes10",
#   "muting": false,
#   "profile_sidebar_border_color": "C0DEED",
#   "contributors_enabled": false,
#   "friends_count": 36,
#   "is_translation_enabled": false,
#   "translator_type": "none",
#   "following": true,
#   "description": "",
#   "has_extended_profile": true,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/996035870829547522/U7gj4B38_normal.jpg",
#   "protected": false,
#   "live_following": false,
#   "is_translator": false,
#   "profile_background_color": "C0DEED",
#   "utc_offset": -25200,
#   "created_at": "Fri Jan 13 15:02:03 +0000 2012",
#   "verified": false,
#   "profile_text_color": "333333",
#   "default_profile_image": false,
#   "profile_use_background_image": true,
#   "location": "",
#   "follow_request_sent": false,
#   "time_zone": "Pacific Time (US & Canada)",
#   "id": 462943965,
#   "lang": "es",
#   "blocking": false,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "url": null,
#   "followers_count": 15,
#   "name": "Rafa Genes"
# }
# {
#   "blocked_by": false,
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#     "description": {
#       "urls": []
#     }
#   },
#   "notifications": false,
#   "listed_count": 1,
#   "geo_enabled": false,
#   "default_profile": true,
#   "id_str": "422727005",
#   "status": {
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_status_id": null,
#     "entities": {
#       "user_mentions": [],
#       "urls": [],
#       "symbols": [],
#       "hashtags": []
#     },
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "id_str": "996409846617559041",
#     "contributors": null,
#     "truncated": false,
#     "place": null,
#     "coordinates": null,
#     "text": "Prueba para streaming de twits",
#     "id": 996409846617559041,
#     "favorited": false,
#     "lang": "es",
#     "retweet_count": 0,
#     "is_quote_status": false,
#     "geo": null,
#     "created_at": "Tue May 15 15:19:54 +0000 2018",
#     "favorite_count": 0,
#     "retweeted": false
#   },
#   "favourites_count": 4,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/378800000392586203/a2c5cc86a7e73e67239fa8d101040610_normal.jpeg",
#   "profile_background_tile": false,
#   "profile_link_color": "1DA1F2",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "statuses_count": 194,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/422727005/1377993020",
#   "screen_name": "BeatJimenez",
#   "muting": false,
#   "profile_sidebar_border_color": "C0DEED",
#   "contributors_enabled": false,
#   "friends_count": 105,
#   "is_translation_enabled": false,
#   "translator_type": "none",
#   "following": true,
#   "description": "",
#   "has_extended_profile": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000392586203/a2c5cc86a7e73e67239fa8d101040610_normal.jpeg",
#   "protected": false,
#   "live_following": false,
#   "is_translator": false,
#   "profile_background_color": "C0DEED",
#   "utc_offset": 10800,
#   "created_at": "Sun Nov 27 16:26:19 +0000 2011",
#   "verified": false,
#   "profile_text_color": "333333",
#   "default_profile_image": false,
#   "profile_use_background_image": true,
#   "location": "",
#   "follow_request_sent": false,
#   "time_zone": "Athens",
#   "id": 422727005,
#   "lang": "es",
#   "blocking": false,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "url": null,
#   "followers_count": 56,
#   "name": "Be\u00f1at Jimenez"
# }
# {
#   "blocked_by": false,
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#     "description": {
#       "urls": []
#     }
#   },
#   "notifications": false,
#   "listed_count": 0,
#   "geo_enabled": false,
#   "default_profile": true,
#   "id_str": "988772074956230658",
#   "status": {
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_status_id": null,
#     "entities": {
#       "user_mentions": [],
#       "urls": [],
#       "symbols": [],
#       "hashtags": []
#     },
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "id_str": "996040375897919488",
#     "contributors": null,
#     "truncated": false,
#     "place": null,
#     "coordinates": null,
#     "text": "Hola mundo!!",
#     "id": 996040375897919488,
#     "favorited": false,
#     "lang": "es",
#     "retweet_count": 0,
#     "is_quote_status": false,
#     "geo": null,
#     "created_at": "Mon May 14 14:51:45 +0000 2018",
#     "favorite_count": 0,
#     "retweeted": false
#   },
#   "favourites_count": 0,
#   "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#   "profile_background_tile": false,
#   "profile_link_color": "1DA1F2",
#   "profile_background_image_url": null,
#   "statuses_count": 1,
#   "screen_name": "mtula99",
#   "muting": false,
#   "profile_sidebar_border_color": "C0DEED",
#   "contributors_enabled": false,
#   "friends_count": 2,
#   "is_translation_enabled": false,
#   "translator_type": "none",
#   "following": true,
#   "description": "",
#   "has_extended_profile": false,
#   "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#   "protected": false,
#   "live_following": false,
#   "is_translator": false,
#   "profile_background_color": "F5F8FA",
#   "utc_offset": null,
#   "created_at": "Tue Apr 24 13:30:07 +0000 2018",
#   "verified": false,
#   "profile_text_color": "333333",
#   "default_profile_image": true,
#   "profile_use_background_image": true,
#   "location": "",
#   "follow_request_sent": false,
#   "time_zone": null,
#   "id": 988772074956230658,
#   "lang": "es",
#   "blocking": false,
#   "profile_background_image_url_https": null,
#   "url": null,
#   "followers_count": 5,
#   "name": "Marc Tula Guardiola"
# }

# %%
for tweet in tweepy.Cursor(api.user_timeline).items(1):
    print(json.dumps(tweet._json, indent=2))
# Out:
# {
#   "in_reply_to_screen_name": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_status_id": null,
#   "entities": {
#     "user_mentions": [],
#     "urls": [
#       {
#         "indices": [
#           37,
#           60
#         ],
#         "display_url": "twitter.com/Tito_Leiva/sta\u2026",
#         "expanded_url": "https://twitter.com/Tito_Leiva/status/996453942296039425",
#         "url": "https://t.co/RmBDhRFbyW"
#       }
#     ],
#     "symbols": [],
#     "hashtags": [
#       {
#         "indices": [
#           0,
#           14
#         ],
#         "text": "Chichichilele"
#       },
#       {
#         "indices": [
#           15,
#           29
#         ],
#         "text": "munmunmundial"
#       },
#       {
#         "indices": [
#           30,
#           36
#         ],
#         "text": "chile"
#       }
#     ]
#   },
#   "retweeted": false,
#   "quoted_status_id": 996453942296039425,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "id_str": "996455235269943296",
#   "truncated": false,
#   "place": null,
#   "possibly_sensitive": false,
#   "coordinates": null,
#   "text": "#Chichichilele #munmunmundial #chile https://t.co/RmBDhRFbyW",
#   "id": 996455235269943296,
#   "user": {
#     "translator_type": "none",
#     "following": false,
#     "description": "",
#     "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#     "has_extended_profile": false,
#     "profile_link_color": "1DA1F2",
#     "entities": {
#       "description": {
#         "urls": []
#       }
#     },
#     "protected": false,
#     "notifications": false,
#     "verified": false,
#     "default_profile_image": true,
#     "profile_background_color": "F5F8FA",
#     "listed_count": 0,
#     "utc_offset": null,
#     "profile_background_tile": false,
#     "geo_enabled": false,
#     "profile_sidebar_fill_color": "DDEEF6",
#     "id_str": "982692299648925696",
#     "is_translator": false,
#     "profile_text_color": "333333",
#     "statuses_count": 7,
#     "profile_use_background_image": true,
#     "contributors_enabled": false,
#     "follow_request_sent": false,
#     "profile_background_image_url_https": null,
#     "favourites_count": 1,
#     "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#     "id": 982692299648925696,
#     "profile_background_image_url": null,
#     "lang": "es",
#     "time_zone": null,
#     "friends_count": 8,
#     "is_translation_enabled": false,
#     "screen_name": "JonathanzPri",
#     "url": null,
#     "followers_count": 4,
#     "profile_sidebar_border_color": "C0DEED",
#     "location": "",
#     "default_profile": true,
#     "created_at": "Sat Apr 07 18:51:16 +0000 2018",
#     "name": "Jonathan Zarama"
#   },
#   "lang": "und",
#   "quoted_status_id_str": "996453942296039425",
#   "favorited": false,
#   "quoted_status": {
#     "in_reply_to_screen_name": "JonathanzPri",
#     "in_reply_to_status_id_str": "996453760200265730",
#     "in_reply_to_status_id": 996453760200265730,
#     "entities": {
#       "user_mentions": [
#         {
#           "indices": [
#             0,
#             13
#           ],
#           "id_str": "982692299648925696",
#           "id": 982692299648925696,
#           "screen_name": "JonathanzPri",
#           "name": "Jonathan Zarama"
#         }
#       ],
#       "urls": [],
#       "symbols": [],
#       "hashtags": []
#     },
#     "retweeted": false,
#     "in_reply_to_user_id": 982692299648925696,
#     "in_reply_to_user_id_str": "982692299648925696",
#     "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "id_str": "996453942296039425",
#     "truncated": false,
#     "place": null,
#     "coordinates": null,
#     "text": "@JonathanzPri Mk te recuerdo el 4-2 de Chile a Colombia",
#     "id": 996453942296039425,
#     "favorited": false,
#     "lang": "es",
#     "user": {
#       "translator_type": "none",
#       "following": true,
#       "description": "Ingeniero Civil Industrial y Comput\u00edn. Futbolero, Judoka, Ciclista, Guitarrero.",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/847827480958390274/bBWysE7r_normal.jpg",
#       "has_extended_profile": true,
#       "profile_link_color": "0084B4",
#       "entities": {
#         "description": {
#           "urls": []
#         },
#         "url": {
#           "urls": [
#             {
#               "indices": [
#                 0,
#                 22
#               ],
#               "display_url": "facebook.com/celeiva815",
#               "expanded_url": "http://www.facebook.com/celeiva815",
#               "url": "http://t.co/xZVVVjjYeV"
#             }
#           ]
#         }
#       },
#       "protected": false,
#       "notifications": false,
#       "verified": false,
#       "default_profile_image": false,
#       "profile_background_color": "C0DEED",
#       "listed_count": 5,
#       "utc_offset": -14400,
#       "profile_background_tile": true,
#       "geo_enabled": true,
#       "profile_sidebar_fill_color": "DDEEF6",
#       "id_str": "154641255",
#       "is_translator": false,
#       "profile_text_color": "333333",
#       "statuses_count": 671,
#       "profile_use_background_image": true,
#       "contributors_enabled": false,
#       "follow_request_sent": false,
#       "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/338612746/colocolo.jpg",
#       "favourites_count": 68,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/847827480958390274/bBWysE7r_normal.jpg",
#       "id": 154641255,
#       "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/338612746/colocolo.jpg",
#       "lang": "es",
#       "time_zone": "Santiago",
#       "friends_count": 140,
#       "is_translation_enabled": false,
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/154641255/1490972873",
#       "screen_name": "Tito_Leiva",
#       "url": "http://t.co/xZVVVjjYeV",
#       "followers_count": 170,
#       "profile_sidebar_border_color": "C0DEED",
#       "location": "\u00d1u\u00f1oa, Chile",
#       "default_profile": false,
#       "created_at": "Fri Jun 11 20:23:13 +0000 2010",
#       "name": "Tito Leiva"
#     },
#     "retweet_count": 0,
#     "is_quote_status": false,
#     "geo": null,
#     "created_at": "Tue May 15 18:15:07 +0000 2018",
#     "favorite_count": 0,
#     "contributors": null
#   },
#   "retweet_count": 0,
#   "is_quote_status": true,
#   "geo": null,
#   "created_at": "Tue May 15 18:20:15 +0000 2018",
#   "favorite_count": 0,
#   "contributors": null
# }
